# %% [markdown]
# ## Computational Physics
#
# textbook: http://www-personal.umich.edu/~mejn/cp/chapters.html

# %% [markdown]
# ### Exercises for chapter 2

# %%
# %matplotlib inline

from pylab import imshow, show, plot, ylim, xlabel, ylabel
from numpy import loadtxt, linspace

data = loadtxt(".\circular.txt",float)
imshow(data)
show()

# %% [markdown]
# ## Exercise 2.1: Another ball dropped from a tower
#
# Euler's identity: $$ e^{i \pi} + 1 = 0 $$
#
# A ball is again dropped from a tower of height h with initial velocity zero. Write a
# program that asks the user to enter the height in meters of the tower and then calculates
# and prints the time the ball takes until it hits the ground, ignoring air resistance. Use
# your program to calculate the time for a ball dropped from a 100 m high tower.

# %%
v0 = 0
h = int( input('What is the height of the tower in meters?') )

s = lambda t : h - ( 9.81*t**2/2 )
v = lambda t : 9.81*t + v0

# %%
x = linspace(0,5,100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 x = linspace(0,5,100)
#
# NameError: name 'linspace' is not defined

# %%
plot(x, s(x))
plot(x, v(x), 'g')
x2 = linspace(-0.5,5.5,5)
plot(x2,[0 for y in x2], 'k--')
show()

# %%
zero_t = (2*h/9.81)**(1/2)

# %%
zero_t
# Out:
# 4.515236409857309

# %%
s(zero_t)
# Out:
# 0.0
